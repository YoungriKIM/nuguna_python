# %%
import pandas as pd

# %%
root_path = 'D:/nuguna_python-1/data/reason_why_not_exercise/Report.xls'
not_exercise = pd.read_excel(root_path)
not_exercise.head()
# Out:
#      기간  대분류   분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0  2019  서울시  서울시               46.8               5.0               4.3
# 1  2019   성별   남자               52.4               4.4               4.9
# 2  2019   성별   여자               42.5               5.6               3.9
# 3  2019  연령별  10대               55.3               4.8               3.9
# 4  2019  연령별  20대               46.0               4.2               4.5
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 0      37.3                5.2  1.4
# 1      32.4                4.9  1.1
# 2      41.0                5.4  1.7
# 3      32.6                3.5    -
# 4      38.8                6.4  0.1

# %%
# 기간이라는 칼럼은 필요가 없으니 없애주자
not_exercise.drop(columns='기간', inplace=True)

# 27번 열부터는 지역 구별 데이터인데 이것들은 필요가 없으니 27번 열부터는 삭제하자
not_exercise.drop(index=range(22, 52), inplace=True)
not_exercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0     서울시           서울시               46.8               5.0
# 1      성별            남자               52.4               4.4
# 2      성별            여자               42.5               5.6
# 3     연령별           10대               55.3               4.8
# 4     연령별           20대               46.0               4.2
# 5     연령별           30대               59.9               5.2
# 6     연령별           40대               54.1               3.9
# 7     연령별           50대               46.1               6.2
# 8     연령별        60대 이상               26.6               6.0
# 9     학력별         중졸 이하               24.7               6.2
# 10    학력별         고졸 이하               44.3               5.3
# 11    학력별         대졸 이하               53.1               4.7
# 12    학력별        대학원 이상               61.2               3.0
# 13    소득별      100만원 미만               10.7               8.4
# ...

# %%
# 0번에 열인 '대분류'별로 데이터를 뽑아 그래프로 확인해보자
not_ex_gender = not_exercise[not_exercise['대분류']=='성별'].copy()
not_ex_gender
# Out:
#   대분류  분류  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 1  성별  남자               52.4               4.4               4.9      32.4
# 2  성별  여자               42.5               5.6               3.9      41.0
#
#    운동을 할 충분한 비용이 없어서   기타
# 1                4.9  1.1
# 2                5.4  1.7

# %%
## 여기서 잠깐 copy() 규칙을 들여다보자
test_a = [1,2,3,4]
print('test_a:', test_a)
